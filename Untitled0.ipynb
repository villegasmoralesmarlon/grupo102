# %%
print("hola mundo")
# Out:
# hola mundo

# %% [markdown]
# creacion de data set# Nueva sección

# %%
#importamos libreria pandas
import pandas as pd

#Asignamos valores a la matriz data
data = [[1,"antonio",20],[2,"jose",34],[3,"luis",24],[4,"mario",25]]
#crcreamos ddataame con la matriz data
df = pd.DataFrame(data, columns=["id", "name", "age"])
#imprimimos dataframe dfS
print(df)
# Out:
#    id     name  age
# 0   1  antonio   20
# 1   2     jose   34
# 2   3     luis   24
# 3   4    mario   25

# %% [markdown]
# Crear un dataframe a partir de un csv# Nueva sección

# %%
import pandas as pd
path ="/content/sample_data/california_housing_train.csv"

df = pd.read_csv(path)

df.describe(include='all').round(1)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# count    17000.0   17000.0             17000.0      17000.0         17000.0
# mean      -119.6      35.6                28.6       2643.7           539.4
# std          2.0       2.1                12.6       2179.9           421.5
# min       -124.4      32.5                 1.0          2.0             1.0
# 25%       -121.8      33.9                18.0       1462.0           297.0
# 50%       -118.5      34.2                29.0       2127.0           434.0
# 75%       -118.0      37.7                37.0       3151.2           648.2
# max       -114.3      42.0                52.0      37937.0          6445.0
#
#        population  households  median_income  median_house_value
# count     17000.0     17000.0        17000.0             17000.0
# mean       1429.6       501.2            3.9            207300.9
# std        1147.9       384.5            1.9            115983.8
# ...
